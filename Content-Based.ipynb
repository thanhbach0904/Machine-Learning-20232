# %%
import pandas as pd

animes = pd.read_csv('anime.csv')
ratings = pd.read_csv('rating.csv')

# %%
animes.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
animes.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
ratings.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
animes = animes[['anime_id','name','genre','type', 'episodes']]
animes.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes
# 0               Drama, Romance, School, Supernatural  Movie        1
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                   Sci-Fi, Thriller     TV       24
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51

# %%
using_table = pd.merge(ratings,animes,on = 'anime_id',how = 'left')
using_table.head(20)
# Out:
#     user_id  anime_id  rating  \
# 0         1        20      -1
# 1         1        24      -1
# 2         1        79      -1
# 3         1       226      -1
# 4         1       241      -1
# 5         1       355      -1
# 6         1       356      -1
# 7         1       442      -1
# 8         1       487      -1
# 9         1       846      -1
# 10        1       936      -1
# 11        1      1546      -1
# 12        1      1692      -1
# 13        1      1836      -1
# 14        1      2001      -1
# 15        1      2025      -1
# 16        1      2144      -1
# 17        1      2787      -1
# 18        1      2993      -1
# 19        1      3455      -1
#
#                                                  name  \
# 0                                              Naruto
# 1                                       School Rumble
# 2                                            Shuffle!
# 3                                          Elfen Lied
# 4                           Girls Bravo: First Season
# 5                                   Shakugan no Shana
# 6                                     Fate/stay night
# 7   Naruto Movie 1: Dai Katsugeki!! Yuki Hime Shin...
# 8                          Girls Bravo: Second Season
# 9                              School Rumble Ni Gakki
# 10  Naruto Movie 2: Dai Gekitotsu! Maboroshi no Ch...
# 11                                           Negima!?
# 12                                            _Summer
# 13                                  Shuffle! Memories
# 14                         Tengen Toppa Gurren Lagann
# 15              Darker than Black: Kuro no Keiyakusha
# 16  Naruto Movie 3: Dai Koufun! Mikazuki Jima no A...
# 17                      Shakugan no Shana II (Second)
# 18                                 Rosario to Vampire
# 19                                         To LOVE-Ru
#
#                                                 genre   type episodes
# 0   Action, Comedy, Martial Arts, Shounen, Super P...     TV      220
# 1                    Comedy, Romance, School, Shounen     TV       26
# 2   Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...     TV       24
# 3   Action, Drama, Horror, Psychological, Romance,...     TV       13
# 4      Comedy, Ecchi, Fantasy, Harem, Romance, School     TV       11
# 5   Action, Drama, Fantasy, Romance, School, Super...     TV       24
# 6       Action, Fantasy, Magic, Romance, Supernatural     TV       24
# 7   Adventure, Comedy, Drama, Historical, Shounen,...  Movie        1
# 8      Comedy, Ecchi, Fantasy, Harem, Romance, School     TV       13
# 9                    Comedy, Romance, School, Shounen     TV       26
# 10  Adventure, Comedy, Drama, Fantasy, Shounen, Su...  Movie        1
# 11  Adventure, Comedy, Ecchi, Fantasy, Harem, Magi...     TV       26
# 12                              Drama, Harem, Romance    OVA        2
# 13  Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...     TV       12
# 14           Action, Adventure, Comedy, Mecha, Sci-Fi     TV       27
# 15               Action, Mystery, Sci-Fi, Super Power     TV       25
# 16                                  Action, Adventure  Movie        1
# 17  Action, Drama, Fantasy, Romance, School, Super...     TV       24
# 18  Comedy, Ecchi, Fantasy, Harem, Romance, School...     TV       13
# 19      Comedy, Ecchi, Harem, Romance, School, Sci-Fi     TV       26

# %%
#delete all the animes with unknown genre
float_genres_row = using_table[using_table['genre'].apply(lambda x: isinstance(x,float))]
using_table = using_table.drop(float_genres_row.index)
using_table.reset_index(drop=True,inplace=True)
# Out:
#    user_id  anime_id  rating                       name  \
# 0        1        20      -1                     Naruto
# 1        1        24      -1              School Rumble
# 2        1        79      -1                   Shuffle!
# 3        1       226      -1                 Elfen Lied
# 4        1       241      -1  Girls Bravo: First Season
#
#                                                genre type episodes
# 0  Action, Comedy, Martial Arts, Shounen, Super P...   TV      220
# 1                   Comedy, Romance, School, Shounen   TV       26
# 2  Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...   TV       24
# 3  Action, Drama, Horror, Psychological, Romance,...   TV       13
# 4     Comedy, Ecchi, Fantasy, Harem, Romance, School   TV       11

# %%
all_tags = list(using_table['genre'].unique()) #all genres of data table
print(all_tags)
# Out:
# ['Action, Comedy, Martial Arts, Shounen, Super Power', 'Comedy, Romance, School, Shounen', 'Comedy, Drama, Ecchi, Fantasy, Harem, Magic, Romance, School, Seinen', 'Action, Drama, Horror, Psychological, Romance, Seinen, Supernatural', 'Comedy, Ecchi, Fantasy, Harem, Romance, School', 'Action, Drama, Fantasy, Romance, School, Supernatural', 'Action, Fantasy, Magic, Romance, Supernatural', 'Adventure, Comedy, Drama, Historical, Shounen, Supernatural', 'Adventure, Comedy, Drama, Fantasy, Shounen, Supernatural', 'Adventure, Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School, Supernatural', 'Drama, Harem, Romance', 'Action, Adventure, Comedy, Mecha, Sci-Fi', 'Action, Mystery, Sci-Fi, Super Power', 'Action, Adventure', 'Comedy, Ecchi, Fantasy, Harem, Romance, School, Shounen, Vampire', 'Comedy, Ecchi, Harem, Romance, School, Sci-Fi', 'Action, Comedy, Ecchi, Harem, Super Power', 'Comedy, Ecchi, Fantasy, Harem, Romance, School, Vampire', 'Comedy, Romance, School, Slice of Life', 'Action, Horror, Martial Arts', 'Comedy, Harem, Romance, School', 'Action, Comedy, Demons, Fantasy, Historical, Shounen, Supernatural', 'Comedy, Ecchi, Harem, Martial Arts, Romance, Shounen', 'Action, Horror', 'Comedy, Ecchi, Harem, School, Sci-Fi, Shounen', 'Action, Comedy, Ecchi, Fantasy, Harem, Mecha, School', 'Comedy, Ecchi, Harem, Romance, Sci-Fi, Shounen, Supernatural', 'Action, Demons, Fantasy, Shounen, Supernatural', 'Action, Comedy, Ecchi, Romance, School, Shoujo Ai, Super Power', 'Action, Comedy, Demons, Ecchi, Harem, Romance, Supernatural', 'Action, Ecchi, Seinen, Super Power, Supernatural', 'Action, Comedy, Drama, School, Supernatural', 'Action, Ecchi, Super Power, Supernatural', 'Action, Comedy, Demons, Fantasy, Shounen, Supernatural', 'Action, Supernatural, Vampire', 'Action, Drama, Fantasy, Romance, Supernatural', 'Comedy, Demons, Parody', 'Action, Comedy, Ecchi, Fantasy, Harem, Magic, School, Shounen', 'Comedy, Ecchi, Harem, Romance, School, Seinen', 'Comedy, Ecchi, Super Power, Supernatural', 'Comedy, Ecchi, Harem, Sci-Fi, Shounen, Supernatural', 'Action, Ecchi, Horror, Supernatural', 'Comedy, Ecchi, Harem, School', 'Comedy, Harem, Romance, Shounen, Supernatural', 'Action, Comedy, Romance, School', 'Action, Comedy, Ecchi, Harem, Magic, Supernatural', 'Action, Comedy, Harem, Mecha, Sci-Fi', 'Action, Comedy, School, Supernatural', 'Comedy, Fantasy, Parody, Shounen, Supernatural', 'Action, Magic, Romance, School, Seinen, Supernatural', 'Action, Drama, Ecchi, Harem, Martial Arts, Romance, Sci-Fi, Seinen', 'Comedy, Ecchi, Supernatural', 'Comedy, Ecchi, School', 'Comedy, Shounen, Supernatural', 'Comedy, Ecchi, Romance, Shounen, Supernatural, Vampire', 'Comedy, Drama, Ecchi, Harem, Romance, Sci-Fi, Shounen, Supernatural', 'Drama, School, Supernatural', 'Action, Comedy, Ecchi, Shoujo Ai, Super Power', 'Comedy, Ecchi, Harem, Romance, School', 'Action, Comedy, Ecchi, School, Supernatural', 'Action, Comedy, Mystery, Romance', 'Comedy, Ecchi, Harem, Romance, School, Seinen, Slice of Life', 'Action, Drama, Sci-Fi, Super Power', 'Comedy, Music, Shounen, Supernatural', 'Comedy, Romance, School, Seinen, Slice of Life', 'Comedy, Ecchi, Romance, School', 'Comedy, Demons, Ecchi, Harem, Romance, School', 'Action, Adventure, Fantasy, Game, Romance', 'Action, Game, Romance, School, Sci-Fi', 'Comedy, School, Shounen, Sports', 'Comedy, Ecchi, Fantasy, Harem, Magic, Romance', 'Comedy, Ecchi, Romance, Supernatural', 'Comedy, Demons, Ecchi, Romance, School', 'Comedy, Ecchi, Harem, Mystery, Romance, School, Seinen', 'Comedy', 'Comedy, Ecchi, Harem, Romance, School, Sci-Fi, Shounen', 'Comedy, Drama, Romance, School, Slice of Life', 'Comedy, Drama, Romance, School', 'Adventure, Demons, Fantasy, Historical, Romance', 'Comedy, Harem, Romance, School, Seinen, Slice of Life', 'Action, Comedy, Demons, Ecchi, Harem, Romance, School', 'Comedy, Harem, Mecha, Romance, School, Sci-Fi', 'Comedy, School, Shounen, Super Power, Supernatural', 'Action, Drama, Fantasy, Shounen, Super Po ...

# %%
genres = []
for tag in all_tags:
    genres1 = tag.split(',')
    genres1 = [i.split() for i in genres1]
    for genre in genres1:
        if genre not in genres:
            genres.append(genre)


for i in range (len(genres)):
    if len(genres[i]) != 1:
        tag = ''
        j = 0
        for char in genres[i]:
            tag += char
            if j != len(genres[i])-1:
                tag += ' '
            j+=1
        genres[i] = [tag]
genres.sort()
print(genres)
print(len(genres))
# Out:
# [['Action'], ['Adventure'], ['Cars'], ['Comedy'], ['Dementia'], ['Demons'], ['Drama'], ['Ecchi'], ['Fantasy'], ['Game'], ['Harem'], ['Hentai'], ['Historical'], ['Horror'], ['Josei'], ['Kids'], ['Magic'], ['Martial Arts'], ['Mecha'], ['Military'], ['Music'], ['Mystery'], ['Parody'], ['Police'], ['Psychological'], ['Romance'], ['Samurai'], ['School'], ['Sci-Fi'], ['Seinen'], ['Shoujo'], ['Shoujo Ai'], ['Shounen'], ['Shounen Ai'], ['Slice of Life'], ['Space'], ['Sports'], ['Super Power'], ['Supernatural'], ['Thriller'], ['Vampire'], ['Yaoi'], ['Yuri']]
# 43

# %%
#create feature vector

# %%
#create utility matrix
